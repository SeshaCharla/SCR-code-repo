# %%
# %run -i calcs.py

# %%
N11 = N[0, 0].factor()
N11
sp.factor_list(N[0,0])[1][2][0].as_poly(s)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 N11 = N[0, 0].factor()
#       2 N11
#       3 sp.factor_list(N[0,0])[1][2][0].as_poly(s)
#
# File ~/anaconda3/lib/python3.10/site-packages/sympy/core/expr.py:3786, in Expr.factor(self, *gens, **args)
#    3784 """See the factor() function in sympy.polys.polytools"""
#    3785 from sympy.polys.polytools import factor
# -> 3786 return factor(self, *gens, **args)
#
# File ~/anaconda3/lib/python3.10/site-packages/sympy/polys/polytools.py:6542, in factor(f, deep, *gens, **args)
#    6539     return f.xreplace(partials)
#    6541 try:
# -> 6542     return _generic_factor(f, gens, args, method='factor')
#    6543 except PolynomialError as msg:
#    6544     if not f.is_commutative:
#
# File ~/anaconda3/lib/python3.10/site-packages/sympy/polys/polytools.py:6223, in _generic_factor(expr, gens, args, method)
# ...

# %%
N12 = N[0, 1].factor()
sp.simplify(N12.subs(subs_dict))
# Out:
# \Theta*\bar k_1*\bar k_{4F}*\bar x_1*\omega_u*b_u*(-V + \bar x_3)/V

# %%
N13 = N[0, 2].factor()
N13
# sp.factor_list(N[0,2])[1][2][0].as_poly(s)
# Out:
# \bar x_1*(g_4 + s)*(-\bar f_{13}*\bar f_{23}*\bar x_1*\bar x_3**2*\delta f_{31} - \bar f_{13}*\bar f_{23}*\bar x_2*\bar x_3**2*\delta f_{32} + \bar f_{13}*\bar f_{23}*\bar x_2*\bar x_3*\delta g_{32} - \bar f_{13}*\bar f_{23}*\bar x_3**2*\delta g_3 + \bar f_{13}*\bar f_{32}*\bar x_2*\bar x_3**2*\delta f_{23} - \bar f_{13}*\bar f_{32}*\bar x_2*\bar x_3*\delta g_{2_T} + \bar f_{13}*\bar f_{32}*\bar x_3**2*\delta g_{23} + \bar f_{13}*\bar g_2*\bar x_1*\bar x_3*\delta f_{31} + \bar f_{13}*\bar g_2*\bar x_2*\bar x_3*\delta f_{32} - \bar f_{13}*\bar g_2*\bar x_2*\delta g_{32} + \bar f_{13}*\bar g_2*\bar x_3*\delta g_3 - \bar f_{13}*\bar g_{32}*\bar x_2*\bar x_3*\delta f_{23} + \bar f_{13}*\bar g_{32}*\bar x_2*\delta g_{2_T} - \bar f_{13}*\bar g_{32}*\bar x_3*\delta g_{23} + \bar f_{13}*\bar x_1*\bar x_3*\delta f_{31}*s + \bar f_{13}*\bar x_2*\bar x_3*\delta f_{32}*s - \bar f_{13}*\bar x_2*\delta g_{32}*s + \bar f_{13}*\bar x_3*\delta g_3*s - \bar f_{23}*\bar f_{31}*\bar x_1*\bar x_3**2*\del
# ...

# %%
N14 = N[0,3].factor()
N14.as_poly(s)
# Out:
# Poly((\bar u_1*\delta b_{11} - \bar x_1*\delta g_{1})*s**3 + (-\bar f_{23}*\bar u_1*\bar x_3*\delta b_{11} + \bar f_{23}*\bar x_1*\bar x_3*\delta g_{1} + \bar f_{31}*\bar u_1*\bar x_1*\delta b_{11} - \bar f_{31}*\bar x_1**2*\delta g_{1} + \bar f_{32}*\bar u_1*\bar x_2*\delta b_{11} - \bar f_{32}*\bar x_1*\bar x_2*\delta g_{1} + \bar g_2*\bar u_1*\delta b_{11} - \bar g_2*\bar x_1*\delta g_{1} + \bar g_3*\bar u_1*\delta b_{11} - \bar g_3*\bar x_1*\delta g_{1} + \bar u_1*\delta b_{11}*g_4 - \bar x_1*\delta g_{1}*g_4)*s**2 + (-\bar f_{13}*\bar f_{32}*\bar x_1*\bar x_2*\bar x_3*\delta g_{2_F} + \bar f_{13}*\bar f_{32}*\bar x_1*\bar x_3*\bar x_4*\delta f_{24} + \bar f_{13}*\bar g_{32}*\bar x_1*\bar x_2*\delta g_{2_F} - \bar f_{13}*\bar g_{32}*\bar x_1*\bar x_4*\delta f_{24} - \bar f_{23}*\bar f_{31}*\bar u_1*\bar x_1*\bar x_3*\delta b_{11} + \bar f_{23}*\bar f_{31}*\bar x_1**2*\bar x_3*\delta g_{1} - \bar f_{23}*\bar g_3*\bar u_1*\bar x_3*\delta b_{11} + \bar f_{23}*\bar g_3*\bar x_1*\bar 
# ...

# %%
N21 = N[1, 0].factor()
sp.simplify((sp.simplify(N21/(s+g4))).subs(subs_dict))
# Out:
# -\bar F*\bar k_1*\bar x_3*(V*\bar k_{4F}*\bar x_2 + k_{4R})/V

# %%
N22 = N[1, 1].factor()
(N22.subs(subs_dict)).as_poly(s)
# Out:
# Poly(\omega_u*b_u/V*s**2 + (V**2*\bar k_1*\bar x_1*\omega_u*b_u + V*\Theta*\bar k_{4F}*\bar x_2*\omega_u*b_u + V*\bar k_1*\bar x_3*\omega_u*b_u + V*\bar k_3*\omega_u*b_u + V*\omega_u*b_u*k_{4R} + \bar F*\omega_u*b_u)/V**2*s + (V*\Theta*\bar k_1*\bar k_{4F}*\bar x_2*\bar x_3*\omega_u*b_u + V*\bar F*\bar k_1*\bar x_1*\omega_u*b_u + V*\bar k_1*\bar k_3*\bar x_3*\omega_u*b_u + V*\bar k_1*\bar x_3*\omega_u*b_u*k_{4R} + \Theta*\bar F*\bar k_{4F}*\bar x_2*\omega_u*b_u + \bar F*\bar k_3*\omega_u*b_u + \bar F*\omega_u*b_u*k_{4R})/V**2, s, domain='ZZ(V,\Theta,\bar F,\bar k_1,\bar k_3,\bar k_{4F},\bar x_1,\bar x_2,\bar x_3,\omega_u,b_u,k_{4R})')

# %%
N23 = N[1, 2].factor()
N23
sp.factor_list(N[1,2])[1][1][0].as_poly(s)
# Out:
# Poly((\bar x_2*\bar x_3*\delta f_{23} - \bar x_2*\delta g_{2_T} + \bar x_3*\delta g_{23})*s**2 + (\bar f_{13}*\bar x_2*\bar x_3**2*\delta f_{23} - \bar f_{13}*\bar x_2*\bar x_3*\delta g_{2_T} + \bar f_{13}*\bar x_3**2*\delta g_{23} - \bar f_{23}*\bar x_1*\bar x_2*\bar x_3*\delta f_{31} - \bar f_{23}*\bar x_2**2*\bar x_3*\delta f_{32} + \bar f_{23}*\bar x_2**2*\delta g_{32} - \bar f_{23}*\bar x_2*\bar x_3*\delta g_3 + \bar f_{31}*\bar x_1*\bar x_2*\bar x_3*\delta f_{23} - \bar f_{31}*\bar x_1*\bar x_2*\delta g_{2_T} + \bar f_{31}*\bar x_1*\bar x_3*\delta g_{23} + \bar f_{32}*\bar x_2**2*\bar x_3*\delta f_{23} - \bar f_{32}*\bar x_2**2*\delta g_{2_T} + \bar f_{32}*\bar x_2*\bar x_3*\delta g_{23} + \bar g_3*\bar x_2*\bar x_3*\delta f_{23} - \bar g_3*\bar x_2*\delta g_{2_T} + \bar g_3*\bar x_3*\delta g_{23} + \bar g_{1}*\bar x_2*\bar x_3*\delta f_{23} - \bar g_{1}*\bar x_2*\delta g_{2_T} + \bar g_{1}*\bar x_3*\delta g_{23} - \bar g_{23}*\bar x_1*\bar x_3*\delta f_{31} - \bar g_{23}*\bar 
# ...

# %%
N24 = N[1, 3].factor()
N24.as_poly(s)
# Out:
# Poly((-\bar x_2*\delta g_{2_F} + \bar x_4*\delta f_{24})*s**3 + (-\bar f_{13}*\bar x_2*\bar x_3*\delta g_{2_F} + \bar f_{13}*\bar x_3*\bar x_4*\delta f_{24} + \bar f_{24}*\bar u_2*\delta b_{42} - \bar f_{31}*\bar x_1*\bar x_2*\delta g_{2_F} + \bar f_{31}*\bar x_1*\bar x_4*\delta f_{24} - \bar f_{32}*\bar x_2**2*\delta g_{2_F} + \bar f_{32}*\bar x_2*\bar x_4*\delta f_{24} - \bar g_3*\bar x_2*\delta g_{2_F} + \bar g_3*\bar x_4*\delta f_{24} - \bar g_{1}*\bar x_2*\delta g_{2_F} + \bar g_{1}*\bar x_4*\delta f_{24} - \bar x_2*\delta g_{2_F}*g_4 + \bar x_4*\delta f_{24}*g_4)*s**2 + (\bar f_{13}*\bar f_{24}*\bar u_2*\bar x_3*\delta b_{42} - \bar f_{13}*\bar f_{32}*\bar x_2**2*\bar x_3*\delta g_{2_F} + \bar f_{13}*\bar f_{32}*\bar x_2*\bar x_3*\bar x_4*\delta f_{24} - \bar f_{13}*\bar g_3*\bar x_2*\bar x_3*\delta g_{2_F} + \bar f_{13}*\bar g_3*\bar x_3*\bar x_4*\delta f_{24} - \bar f_{13}*\bar x_2*\bar x_3*\delta g_{2_F}*g_4 + \bar f_{13}*\bar x_3*\bar x_4*\delta f_{24}*g_4 - \bar f_{23}*\ba
# ...

# %%
G
# Out:
# Matrix([
# ...

# %%
z = sp.symbols('z')
T = sp.symbols('T')
Gz = (1-(1/z))*(G/s).subs(s, (2/T)*(z-1)/(z+1))

# %%
Dz = (D*s).subs(s, (2/T)*(z-1)/(z+1))
Dz.expand()
Dz.simplify()
# Out:
# 2*(z - 1)*(T*g_4*(z + 1) + 2*z - 2)*(T**3*(z + 1)**3*(-\bar f_{13}*\bar f_{23}*\bar g_3*\bar x_3**2 - \bar f_{13}*\bar f_{23}*\bar g_{32}*\bar x_2*\bar x_3 + \bar f_{13}*\bar f_{32}*\bar g_2*\bar x_2*\bar x_3 + \bar f_{13}*\bar f_{32}*\bar g_{23}*\bar x_3**2 + \bar f_{13}*\bar g_2*\bar g_3*\bar x_3 - \bar f_{13}*\bar g_{23}*\bar g_{32}*\bar x_3 - \bar f_{23}*\bar f_{31}*\bar g_{1}*\bar x_1*\bar x_3 - \bar f_{23}*\bar g_3*\bar g_{1}*\bar x_3 - \bar f_{23}*\bar g_{1}*\bar g_{32}*\bar x_2 + \bar f_{31}*\bar g_2*\bar g_{1}*\bar x_1 + \bar f_{32}*\bar g_2*\bar g_{1}*\bar x_2 + \bar f_{32}*\bar g_{1}*\bar g_{23}*\bar x_3 + \bar g_2*\bar g_3*\bar g_{1} - \bar g_{1}*\bar g_{23}*\bar g_{32}) + 2*T**2*(z - 1)*(z + 1)**2*(-\bar f_{13}*\bar f_{23}*\bar x_3**2 + \bar f_{13}*\bar f_{32}*\bar x_2*\bar x_3 + \bar f_{13}*\bar g_2*\bar x_3 + \bar f_{13}*\bar g_3*\bar x_3 - \bar f_{23}*\bar f_{31}*\bar x_1*\bar x_3 - \bar f_{23}*\bar g_3*\bar x_3 - \bar f_{23}*\bar g_{1}*\bar x_3 - \bar f_{23}*\bar g_{
# ...
